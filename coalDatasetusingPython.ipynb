# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/7 to 9/Project/DATASET Iron ore_And Coal Analysis/CoalIndia.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj_Close  \
# 0     30-12-2010  311.000000  311.600006  307.000000  308.049988  117.816864
# 1     31-12-2010  309.500000  316.450012  308.299988  314.750000  120.379372
# 2     03-01-2011  315.500000  318.000000  314.549988  317.299988  121.354622
# 3     04-01-2011  318.899994  320.000000  316.049988  319.200012  122.081299
# 4     05-01-2011  320.000000  320.000000  308.250000  309.799988  118.486183
# ...          ...         ...         ...         ...         ...         ...
# 3207  22-12-2023  359.000000  367.399994  356.399994  363.250000  363.250000
# 3208  26-12-2023  363.799988  371.799988  362.500000  366.049988  366.049988
# 3209  27-12-2023  367.000000  369.200012  362.399994  365.600006  365.600006
# 3210  28-12-2023  366.799988  382.500000  365.799988  380.950012  380.950012
# 3211  29-12-2023  381.500000  381.700012  374.250000  376.000000  376.000000
#
#           Volume
# 0      2643251.0
# ...

# %%
print(df.head())
# Out:
#          Date        Open        High         Low       Close   Adj_Close  \
# 0  30-12-2010  311.000000  311.600006  307.000000  308.049988  117.816864
# 1  31-12-2010  309.500000  316.450012  308.299988  314.750000  120.379372
# 2  03-01-2011  315.500000  318.000000  314.549988  317.299988  121.354622
# 3  04-01-2011  318.899994  320.000000  316.049988  319.200012  122.081299
# 4  05-01-2011  320.000000  320.000000  308.250000  309.799988  118.486183
#
#       Volume
# 0  2643251.0
# 1  4960987.0
# 2  2929118.0
# 3  2716995.0
# 4  8555905.0

# %%
print(df.describe())
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  3206.000000  3206.000000  3206.000000  3206.000000  3206.000000
# mean    271.535964   274.960979   267.840003   271.311088   151.746668
# std      77.337925    78.299716    76.366272    77.327260    40.175368
# min     110.849998   112.449997   109.550003   110.550003    76.384781
# 25%     217.387501   220.350006   214.525002   217.162495   125.461668
# 50%     282.199997   285.925003   278.349991   282.375000   149.131836
# 75%     332.575004   336.287506   327.537491   331.987503   168.125443
# max     445.000000   447.100006   437.000000   443.399994   380.950012
#
#              Volume
# count  3.206000e+03
# mean   6.762198e+06
# std    7.517547e+06
# min    0.000000e+00
# 25%    2.497198e+06
# 50%    4.238304e+06
# 75%    8.397556e+06
# max    1.009886e+08

# %%
print(df.isnull().sum())
# Out:
# Date         0
# Open         6
# High         6
# Low          6
# Close        6
# Adj_Close    6
# Volume       6
# dtype: int64

# %%
print("Mean:")
print(df.describe().mean())
print("\nMedian:")
print(df.describe().median())
print("\nStandard Deviation:")
print(df.describe().std())
print("\nSkewness:")
print(df.describe().skew())
print("\nKurtosis:")
print(df.describe().kurtosis())
# Out:
# Mean:
# Open         6.178608e+02
# High         6.201717e+02
# Low          6.146461e+02
# Close        6.175142e+02
# Adj_Close    5.372470e+02
# Volume       1.630058e+07
# dtype: float64
#
# Median:
# Open         2.768680e+02
# High         2.804430e+02
# Low          2.730950e+02
# Close        2.768430e+02
# Adj_Close    1.504393e+02
# Volume       5.500251e+06
# dtype: float64
#
# Standard Deviation:
# Open         1.052341e+03
# High         1.051476e+03
# Low          1.053392e+03
# Close        1.052437e+03
# Adj_Close    1.083065e+03
# Volume       3.437190e+07
# dtype: float64
#
# Skewness:
# Open         2.758353
# High         2.757527
# Low          2.761023
# Close        2.758802
# Adj_Close    2.780697
# Volume       2.778275
# dtype: float64
#
# Kurtosis:
# Open         7.703266
# High         7.700054
# Low          7.714665
# Close        7.705265
# Adj_Close    7.789015
# Volume       7.788605
# dtype: float64

# %% [raw]
# Business moments analysis

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Close'])
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.show()

# %%
print("Volume Statistics:")
print(df['Volume'].describe())
# Out:
# Volume Statistics:
# count    3.206000e+03
# mean     6.762198e+06
# std      7.517547e+06
# min      0.000000e+00
# 25%      2.497198e+06
# 50%      4.238304e+06
# 75%      8.397556e+06
# max      1.009886e+08
# Name: Volume, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Volume'], bins=30, edgecolor='black')
plt.title('Distribution of Daily Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Close'])
plt.title('Boxplot of Close Price')
plt.ylabel('Close Price')
plt.grid(True)
plt.show()
