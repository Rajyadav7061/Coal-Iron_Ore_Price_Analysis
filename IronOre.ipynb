# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st

# %%
df = pd.read_csv("D:/7 to 9/Project/DATASET Iron ore_And Coal Analysis/Iron Ore 1.csv")

# %%
print(df)
# Out:
#           Date   High    Low   Open  Close   Volume
# 0    19-Apr-24  30.76  29.28  30.65  30.21  620.77K
# 1    12-Apr-24  30.70  29.23  29.32  30.45  804.79K
# 2    05-Apr-24  29.65  28.52  29.06  29.21    1.01M
# 3    28-Mar-24  29.76  28.81  29.25  28.88  787.04K
# 4    22-Mar-24  29.93  28.92  29.30  29.27    1.23M
# ..         ...    ...    ...    ...    ...      ...
# 256  24-May-19  33.32  30.64  33.19  31.00  841.70K
# 257  17-May-19  33.23  29.81  30.40  33.13    1.05M
# 258  10-May-19  31.29  28.88  29.01  30.68    1.11M
# 259  03-May-19  31.49  28.97  30.31  29.42  733.15K
# 260  26-Apr-19  32.46  29.91  31.75  30.32  582.65K
#
# [261 rows x 6 columns]

# %%
print(df.head())
# Out:
#         Date   High    Low   Open  Close   Volume
# 0  19-Apr-24  30.76  29.28  30.65  30.21  620.77K
# 1  12-Apr-24  30.70  29.23  29.32  30.45  804.79K
# 2  05-Apr-24  29.65  28.52  29.06  29.21    1.01M
# 3  28-Mar-24  29.76  28.81  29.25  28.88  787.04K
# 4  22-Mar-24  29.93  28.92  29.30  29.27    1.23M

# %%
print(df.describe())
# Out:
#              High         Low        Open       Close
# count  261.000000  261.000000  261.000000  261.000000
# mean    32.896169   30.683065   31.813640   31.835211
# std      7.123534    6.748870    7.026545    7.034688
# min     16.420000   13.250000   14.280000   14.410000
# 25%     28.080000   26.120000   27.110000   27.110000
# 50%     32.140000   30.440000   31.360000   31.400000
# 75%     36.910000   34.430000   35.900000   35.780000
# max     51.000000   48.000000   51.000000   50.220000

# %%
print(df.isnull().sum())
# Out:
# Date      0
# High      0
# Low       0
# Open      0
# Close     0
# Volume    0
# dtype: int64

# %%
print("Mean:")
print(df.describe().mean())
print("\nMedian:")
print(df.describe().median())
print("\nStandard Deviation:")
print(df.describe().std())
print("\nSkewness:")
print(df.describe().skew())
print("\nKurtosis:")
print(df.describe().kurtosis())
# Out:
# Mean:
# High     58.196213
# Low      56.333992
# Open     57.436273
# Close    57.348737
# dtype: float64
#
# Median:
# High     32.518084
# Low      30.561533
# Open     31.586820
# Close    31.617605
# dtype: float64
#
# Standard Deviation:
# High     82.992202
# Low      83.660610
# Open     83.326558
# Close    83.327035
# dtype: float64
#
# Skewness:
# High     2.687021
# Low      2.699393
# Open     2.684531
# Close    2.688896
# dtype: float64
#
# Kurtosis:
# High     7.410472
# Low      7.460463
# Open     7.396341
# Close    7.416067
# dtype: float64

# %%
print("Volume Statistics:")
print(df['Volume'].describe())
# Out:
# Volume Statistics:
# count       261
# unique      187
# top       1.46M
# freq          6
# Name: Volume, dtype: object

# %%
plt.hist(df['Volume'], bins=50, edgecolor='black')
plt.title('Volume Distribution')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Close'])
plt.title('Closing Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Close'])
plt.title('Boxplot of Close Price')
plt.ylabel('Close Price')
plt.grid(True)
plt.show()
